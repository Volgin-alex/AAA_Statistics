# %% [markdown]
# # Алгорим A/B

# %% [markdown]
# 1. **Бизнес задача/Бизнес-гипотеза** *Прибыльность бизнес модели (заказ забирают больше чем в половину)*
# 2. **H0: $\mu=0.5$, H1: $\mu>0.5$ Гипотеза**
# 3. **Статистика Q = сумма успехов = $\sum\limits_{i=1}^{n}Bernulli(\mu)$ q=(19)**
# 4. **Как Q распределена, если верна H0** (*Участок площади $\alpha$ называется критической областью* в него попадают пользователи **редко** с вероятностью $\alpha$ случаев) И если мы будем каждый раз попадая в крит область отвергать H1, то мы будем совершать ошибку `I рода` с вероятностью $\alpha$. Если наша $\mu$ в реальности сильно больше, то мы будем **часто** попадать в критическую область и вот это **часто** называется **Мощьность**
# Когда мы провели эксперимент и посчитали q, то площадь от **P-value** от q и все более экстремальные значения и сравнить их с $\alpha$, если p-value <= $\alpha$, то отвергаем H0
# 5. **MDE(*размер выборки*, *Power-вероятность ошибки II рода*, *$\alpha$*)** Теперь фиксируем ошибку `II рода`
# 6. **Доверительный интервал, для истинного эффекта $\mu \in [0.55.....0.87]$**
